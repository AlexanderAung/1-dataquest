# %%
import matplotlib.pyplot as plt

# %%
data1 = ["Alice", "Bob", "Chow", "Dick", "Elon"]
data2 = [200000, 300000, 250000, 300000, 400000]

# %%
plt.xlabel("Employee")
plt.ylabel("Salary")
plt.plot(data1, data2)
